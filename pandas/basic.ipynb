# %%
import pandas as pd

# %%
data = {
    "Name": ["Rahul", "Aman", "Neha"],
    "Age": [22, 24, 21],
    "marks":[85,56,45],
    "City": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  marks    City
# 0  Rahul   22     85   Delhi
# 1   Aman   24     56  Mumbai
# 2   Neha   21     45    Pune

# %%
df.to_csv("student1.csv",index=False)

# %%
df=pd.read_csv("student.csv",sep=";")
df
# Out:
#                 Name  Age,marks,City
# 0  Rahul,22,85,Delhi             NaN
# 1  Aman,24,56,Mumbai             NaN
# 2    Neha,21,45,Pune             NaN

# %%
df=pd.read_csv("student.csv",header=None)
df
# Out:
#        0    1      2       3
# 0   Name  Age  marks    City
# 1  Rahul   22     85   Delhi
# 2   Aman   24     56  Mumbai
# 3   Neha   21     45    Pune

# %%
pd.read_csv("student.csv", usecols=["Name", "marks"])
# Out:
#     Name  marks
# 0  Rahul     85
# 1   Aman     56
# 2   Neha     45

# %%
pd.read_csv("student.csv", na_values=["NA", "null", "-"])
# Out:
#     Name   Age marks   City
# 0  Rahul  22.0    85  Delhi
# 1   Aman   NaN  none    NaN
# 2    NaN  21.0    45   Pune
